# %% [markdown]
# # Facial Recognition using DeepFace Pypi

# %%
pip install deepface

# %% [markdown]
# # Import Basic Libraries

# %%
from deepface import DeepFace
import matplotlib.pyplot as plt
import cv2 as cv
import os

# %% [markdown]
# # Read Predictive Image

# %%
prefix = 'dataset/img'
length = len(os.listdir("dataset"))
image_type = ".jpg"
image_path = prefix+input("Please enter the image number from 1 to "+str(length)+ "= ")+image_type
# Out:
# Please enter the image number from 1 to 64= 64

# %%
print(image_path)
# Out:
# dataset/img64.jpg

# %%
img = cv.imread(image_path)

# %% [markdown]
# # Print Image Property

# %%
print("type of image is= ", type(img))
print("Image matrices are:\n")
print(img)
# Out:
# type of image is=  <class 'numpy.ndarray'>
# Image matrices are:
#
# [[[214 204 216]
#   [196 186 198]
#   [193 180 194]
#   ...
#   [172 154 177]
#   [171 154 175]
#   [172 153 174]]
#
#  [[215 206 216]
#   [197 187 199]
#   [194 182 194]
#   ...
#   [176 159 180]
#   [175 158 179]
#   [174 157 178]]
#
#  [[217 208 218]
#   [199 190 200]
#   [193 183 195]
#   ...
#   [181 164 185]
#   [181 164 185]
#   [181 165 183]]
#
#  ...
#
#  [[255 252 251]
#   [255 252 251]
#   [254 252 251]
#   ...
#   [253 255 255]
#   [253 255 255]
#   [253 255 255]]
#
#  [[255 252 251]
#   [255 252 251]
#   [254 252 251]
#   ...
#   [253 255 255]
#   [253 255 255]
#   [253 255 255]]
#
#  [[255 252 251]
#   [255 252 251]
#   [254 252 251]
#   ...
#   [253 255 255]
#   [253 255 255]
#   [253 255 255]]]

# %% [markdown]
# # Model Prediction

# %%
result = DeepFace.analyze(img)
# Out:
# Actions to do:  ['emotion', 'age', 'gender', 'race']
# Analyzing:   0%|          | 0/1 [00:00<?, ?it/s]
# Finding actions:   0%|          | 0/4 [00:00<?, ?it/s]
# Action: emotion:   0%|          | 0/4 [00:00<?, ?it/s]
# Action: emotion:  25%|██▌       | 1/4 [00:03<00:11,  3.87s/it]
# Action: age:  25%|██▌       | 1/4 [00:03<00:11,  3.87s/it]
# Action: age:  50%|█████     | 2/4 [00:05<00:06,  3.09s/it]
# Action: gender:  50%|█████     | 2/4 [00:05<00:06,  3.09s/it]
# Action: gender:  75%|███████▌  | 3/4 [00:06<00:02,  2.46s/it]
# Action: race:  75%|███████▌  | 3/4 [00:06<00:02,  2.46s/it]
# Action: race: 100%|██████████| 4/4 [00:07<00:00,  1.80s/it]
# Analyzing:   0%|          | 0/1 [00:07<?, ?it/s]

# %% [markdown]
# # Visualization

# %%
plt.imshow(img[:,:,::-1]) #BRG -> RGB
plt.xticks(())
plt.yticks(())
plt.title("Hello "+result['gender'])
# Out:
# Text(0.5, 1.0, 'Hello Man')

# %% [markdown]
# # Image Analysis

# %%
from sklearn import preprocessing as p

print("Enter 1 for emotion prediction!")
print("Enter 2 for age prediction!")
print("Enter 3 for gender prediction!")
print("Enter 4 for race prediction!")
print("Enter 0 to exit!")

loop = 1

while loop !=0:
    option = int(input("Kindly enter your choice= "))
    if option==0:
        loop=0
    elif option==1:
        print('\nEmotions:')
        print("Angry: ",result['emotion']['angry'])
        print("Disgust: ",result['emotion']['disgust'])
        print("Fear: ",result['emotion']['fear'])
        print("Happy: ",result['emotion']['happy'])
        print("Sad: ",result['emotion']['sad'])
        print("Surprise: ",result['emotion']['surprise'])
        print("Neutral: ",result['emotion']['neutral'])
        print()
    elif option==2:
        print('\nAge: ',result['age'])
        print()
    elif option==3:
        print('\nGender: ',result['gender'])
        print()
    else:
        print('Race:')
        print("Asian: ",result['race']['asian'])
        print("Indian: ",result['race']['indian'])
        print("Black: ",result['race']['black'])
        print("White: ",result['race']['white'])
        print("Middle Eastern: ",result['race']['middle eastern'])
        print("Latino Hispanic: ",result['race']['latino hispanic'])
        print()
# Out:
# Enter 1 for emotion prediction!
# Enter 2 for age prediction!
# Enter 3 for gender prediction!
# Enter 4 for race prediction!
# Enter 0 to exit!
# Kindly enter your choice= 1
#
# Emotions:
# Angry:  27.1923691034317
# Disgust:  7.284968432941241e-05
# Fear:  5.0093840807676315
# Happy:  0.00250853208854096
# Sad:  33.87133181095123
# Surprise:  0.0071594855398871005
# Neutral:  33.917176723480225
#
# Kindly enter your choice= 2
#
# Age:  31.966956280901144
